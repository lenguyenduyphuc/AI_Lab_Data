# %%
from pathlib import Path
import json
import time
import datetime
import os
import pandas as pd
from tqdm.auto import tqdm
from google import genai
from google.genai import types

# %%
# --- Configuration ---
SYSTEM_PROMPT = """
You are a **Senior Safety Analyst and Behavioral Scientist** specializing in digital communications. Your mission is to annotate online messages (e.g., social media posts, private messages, forum discussions, chat logs) to build and refine intelligent safety systems. Your expert annotations are critical for training AI models to detect and intervene in real-time situations involving emotional distress, predatory behavior, and self-harm. You must operate with clinical precision, objectivity, and a deep understanding of online communication nuances.

---
### **Core Objective**
To accurately identify and label specific risk categories within digital messages to enable AI-driven safety interventions. Your analysis must be grounded solely in the provided text, without making external assumptions.

---
### **1. Label Set & Definitions**
Assign one or more of the following labels to each message.

* **`Suicidal Reference`**
    * **Definition:** Any explicit or implicit mention of suicide, self-harm, or the desire to end one's life. This includes expressing feelings of being a burden, having a plan, or saying goodbye in a terminal way.
    * **Keywords:** *kill myself, end it all, not be here anymore, tired of living, better off without me, self-harm, cutting.*
    * **Examples:**
        * *"I can't take this pain anymore. I think I'm just going to end it."*
        * *"Everyone would be happier if I wasn't around."*
        * *"Just bought a rope. It's time to say goodbye."*
        * *"Thinking about overdosing again tonight."*

* **`Emotional Distress`**
    * **Definition:** Clear indicators of significant psychological or emotional suffering, such as depression, severe anxiety, hopelessness, or intense emotional pain that is not suicidal in nature.
    * **Keywords:** *depressed, empty, worthless, can't stop crying, panic attack, crippled by anxiety, hate myself, everything is pointless.*
    * **Examples:**
        * *"I just feel so hollow inside, like nothing matters anymore."*
        * *"This overwhelming sadness won't go away and I don't know why."*
        * *"I've been having panic attacks all week and I can't leave my room."*
        * *"I feel completely worthless and alone."*

* **`Attacking Behavior`**
    * **Definition:** Any hostile action directed at another individual or group. This is a broad category that includes threats, bullying, harassment, intimidation, and predatory grooming behavior.
    * **Subcategories to consider:**
        * **Predatory Grooming:** Attempts to build trust with a minor for exploitation, suggesting secrets, or asking for inappropriate content.
        * **Threats:** Explicit or implicit statements of intent to cause harm to others.
        * **Bullying/Harassment:** Persistent insults, mockery, humiliation, or spreading rumors.
        * **Intimidation:** Using fear or power to control someone's actions.
    * **Examples:**
        * *(Grooming)*: *"Your parents wouldn't understand our connection. This is our special secret."*
        * *(Threat)*: *"You better watch your back. I know where you live."*
        * *(Bullying)*: *"Everyone is laughing at you. You're such a loser."*
        * *(Intimidation)*: *"If you tell anyone about this, I'll make sure you regret it."*

* **`Safe/Neutral`**
    * **Definition:** The message shows no signs of the risk categories above. It can be positive, informative, mundane, or emotionally balanced. This label **cannot** be used with any other label.
    * **Examples:**
        * *"Just finished a great workout! Feeling energized."*
        * *"What time is the meeting tomorrow?"*
        * *"Happy birthday! Hope you have an amazing day."*

* **`Unclear`**
    * **Definition:** The message is too ambiguous, lacks critical context, or is too short to make a confident judgment. This is used when the intent cannot be reasonably determined. This label **cannot** be used with any other label.
    * **Examples:**
        * *"I'm done."* (Could be suicidal, angry, or simply finished with a task.)
        * *"Whatever."*
        * *"He'll be sorry."* (Could be a threat or just venting frustration.)

---
### **2. Labeling Instructions & Cognitive Workflow**

Follow this process for every message:

1.  **Initial Read-Through:** Read the message to get a general sense of its content and tone.
2.  **Risk Analysis:** Actively screen for indicators of `Suicidal Reference`, `Emotional Distress`, and `Attacking Behavior`.
    * Does the message mention self-harm or ending a life? -> **`Suicidal Reference`**.
    * Does it express intense sadness, hopelessness, or anxiety without being suicidal? -> **`Emotional Distress`**.
    * Is it directed at another person in a threatening, bullying, or grooming manner? -> **`Attacking Behavior`**.
3. **Labels:** Only use 5 given labels, do not use anything besides Suicidal Reference, Emotional Distress, Attacking Behavior, Safe/Neutral and Unclear
4.  **Contextual Judgment:**
    * A single message may contain multiple risk factors. For example, a message threatening self-harm *in order to manipulate someone* could be labeled both `Suicidal Reference` and `Attacking Behavior`.
    * If no risk indicators are present, label it **`Safe/Neutral`**.
    * If the meaning is genuinely ambiguous after careful consideration and you cannot confidently choose a label, use **`Unclear`**. Do not guess.
5.  **Final Verification:** Ensure your chosen labels strictly adhere to the definitions. Confirm that `Safe/Neutral` or `Unclear` are not combined with other labels.
6.  **Format Output:** Structure your final response **only** in the specified JSON format.

---
### **3. Response Format**

Your response must be a valid JSON object containing a single key, `"labels"`, with its value being a list of strings. The list must contain one or more of the approved labels.

**--- Example Outputs ---**

`{"labels": ["Emotional Distress"]}`

`{"labels": ["Suicidal Reference", "Emotional Distress"]}`

`{"labels": ["Attacking Behavior"]}`

`{"labels": ["Safe/Neutral"]}`

`{"labels": ["Unclear"]}`
"""

# %%
INPUT_FILE = Path("Twitter.xlsx")       
GEMINI_MODEL = "gemini-2.5-flash-preview-05-20"  
CHUNK_SIZE = 10
GEMINI_API_KEY = os.environ["GEMINI_API_KEY"]

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

def label_text(text: str) -> dict[str, list[str]]:
    text = (text or "").strip()
    if not text:
        return {"labels": ["Unclear - Empty Text"]}
    
    prompt = f"{SYSTEM_PROMPT}\n\nText to classify:\n{text}"
    
    try:
        resp = client.models.generate_content(
            model=GEMINI_MODEL,
            contents=[prompt],
            config=types.GenerateContentConfig(
                response_mime_type="application/json", 
                temperature=0
            ),
        )
        candidate = resp.candidates[0]
        if candidate.finish_reason != "STOP":
            return {"labels": ["Error - Response Blocked"]}
        if candidate.content is None:
            return {"labels": ["Error - No Content"]}
        if not candidate.content.parts or len(candidate.content.parts) == 0:
            return {"labels": ["Error - No Parts"]}
        response_content = candidate.content.parts[0].text
        if response_content is None:
            return {"labels": ["Error - No Text"]}
        
        # Parse JSON
        try:
            result = json.loads(response_content)
            if "labels" not in result:
                return {"labels": ["Error - Invalid Format"]}
            return {"labels": result["labels"]}
        except json.JSONDecodeError as e:
            return {"labels": ["Error - Invalid JSON"]}
            
    except Exception as e:
        print(f"API call failed: {e}")
        return {"labels": ["Error - API Failure"]}

# %%
def main() -> None:
    print(f"Loading data from {INPUT_FILE}…")
    try:
        all_sheets = pd.read_excel(INPUT_FILE, sheet_name=None)
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return

    # Gather every "body" column we can find
    bodies = (
        pd.concat(
            [df["body"] for df in all_sheets.values() if "body" in df.columns],
            ignore_index=True
        )
        .dropna()
        .astype(str)
    )

    bodies = bodies[~bodies.str.strip().str.lower().isin(["[removed]", "[deleted]"])]

    # subset_df = bodies.iloc[458020:].reset_index(drop=True).to_frame(name="body")
    # subset_df["labels"] = "" 
    # total_rows = len(subset_df)
    # print(f"Selected {total_rows} messages for labelling.")

    subset_df = bodies.reset_index(drop=True).to_frame(name="body")
    subset_df["labels"] = ""  # placeholder column
    total_rows = len(subset_df)
    print(f"Selected {total_rows} messages for labelling.")

    # Pre-compute filenames
    ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    final_outfile = INPUT_FILE.with_name(f"Toxicity_2_{ts}.xlsx")
    progress_file = INPUT_FILE.with_name(f"Toxicity_2_cp_{ts}.xlsx")

    print("Starting labelling process…")
        
    for idx, msg in enumerate(tqdm(subset_df["body"], desc="Labelling", total=total_rows), 1):
        time.sleep(0.2)
                
        # Get labels for the message
        rec = label_text(msg)
        labels_list = rec.get("labels", ["Unclear - Processing Error"])
        subset_df.at[idx - 1, "labels"] = ", ".join(labels_list)

        # Checkpoint save
        if idx % CHUNK_SIZE == 0 or idx == total_rows:
            try:
                subset_df.iloc[:idx].to_excel(progress_file, index=False)
                print(f"✓ Checkpoint: ({idx}/{total_rows}) ➜ {progress_file}")
            except Exception as e:
                print(f"Warning: Could not save checkpoint: {e}")

    # Final save
    try:
        subset_df.to_excel(final_outfile, index=False)
        print(f"✓ Finished. Full file saved ➜ {final_outfile}")
    except Exception as e:
        print(f"Error saving final file: {e}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading data from Twitter.xlsx…
# Selected 3075 messages for labelling.
# Starting labelling process…
# Labelling:   0%|          | 0/3075 [00:00<?, ?it/s]
# ✓ Checkpoint: (10/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (20/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (30/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (40/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (50/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (60/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (70/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (80/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (90/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (100/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (110/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (120/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (130/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (140/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (150/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (160/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (170/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (180/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (190/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (200/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (210/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (220/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (230/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (240/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (250/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (260/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (270/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (280/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (290/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (300/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (310/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (320/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (330/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (340/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (350/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (360/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (370/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (380/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (390/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (400/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (410/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (420/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (430/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (440/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (450/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (460/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (470/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (480/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (490/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (500/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (510/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (520/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (530/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (540/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (550/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (560/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (570/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (580/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (590/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (600/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (610/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (620/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (630/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (640/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (650/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (660/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (670/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (680/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (690/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (700/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (710/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (720/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (730/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (740/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (750/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (760/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (770/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (780/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (790/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (800/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (810/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (820/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (830/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (840/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (850/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (860/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (870/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (880/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (890/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (900/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (910/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (920/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (930/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (940/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (950/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (960/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (970/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (980/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (990/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1000/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1010/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1020/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1030/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1040/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1050/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1060/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1070/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1080/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1090/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1100/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1110/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1120/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1130/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1140/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1150/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1160/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1170/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1180/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1190/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1200/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1210/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1220/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1230/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1240/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1250/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1260/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1270/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1280/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1290/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1300/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1310/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1320/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1330/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1340/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1350/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1360/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1370/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1380/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1390/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1400/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1410/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1420/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1430/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1440/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1450/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1460/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1470/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1480/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1490/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1500/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1510/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1520/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1530/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1540/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1550/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1560/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1570/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1580/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1590/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1600/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1610/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1620/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1630/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1640/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1650/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1660/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1670/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1680/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1690/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1700/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1710/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1720/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1730/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1740/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1750/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1760/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1770/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1780/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1790/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1800/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1810/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1820/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1830/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1840/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1850/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1860/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1870/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1880/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1890/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1900/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1910/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1920/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1930/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1940/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1950/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1960/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1970/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1980/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (1990/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2000/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2010/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2020/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2030/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2040/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2050/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2060/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2070/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2080/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2090/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2100/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2110/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2120/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2130/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2140/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2150/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2160/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2170/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2180/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2190/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2200/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2210/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2220/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2230/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2240/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2250/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2260/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2270/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2280/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2290/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2300/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2310/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2320/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2330/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2340/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2350/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2360/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2370/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2380/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2390/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2400/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2410/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2420/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2430/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2440/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2450/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2460/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2470/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2480/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2490/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2500/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2510/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2520/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2530/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2540/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2550/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2560/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2570/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2580/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2590/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2600/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2610/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2620/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2630/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2640/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2650/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2660/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2670/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2680/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2690/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2700/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2710/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2720/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2730/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2740/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2750/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2760/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2770/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2780/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2790/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2800/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2810/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2820/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2830/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2840/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2850/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2860/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2870/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2880/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2890/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2900/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2910/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2920/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2930/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2940/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2950/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2960/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2970/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2980/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (2990/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3000/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3010/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3020/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3030/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3040/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3050/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3060/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3070/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Checkpoint: (3075/3075) ➜ Toxicity_2_cp_20250612_164618.xlsx
# ✓ Finished. Full file saved ➜ Toxicity_2_20250612_164618.xlsx
