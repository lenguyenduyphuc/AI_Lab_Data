# %%
from pathlib import Path
import json
import time
import datetime
import os
import pandas as pd
from tqdm.auto import tqdm
from google import genai
from google.genai import types

# %%
# --- Configuration ---
SYSTEM_PROMPT = """
You are an expert annotator responsible for labeling online messages to support AI systems that detect mental health risks, predatory behavior, and emotional distress. Your output will be used to train models for real-time safety monitoring.

Objective: Create high-quality labeled data for training AI models that can detect predatory behaviors, emotional distress, and mental health risks in online communications.

===========================
1) Label Set (Choose one or more)
===========================

• Suicidal Reference
  - Mentions or implies suicidal thoughts, ideation, or self-harm
  - Example: "Sometimes I think about ending it all."

• Emotional Distress
  - Signs of depression, anxiety, emotional suffering, psychological struggle
  - Example: "I just feel so lost lately, like nothing matters."

• Attacking Behavior
  - Bullying, sexually predatory content, threats, grooming, or intimidation
  - Example: "Don't tell your parents — it's our secret, okay?"

• Safe/Neutral
  - No concerning behavior, emotionally balanced, or informative
  - Example: "I got an A on my exam! So happy right now!"

• Unclear
  - Too vague or ambiguous to confidently assign a label
  - Example: "I'm fine." (without context)

===========================
2) Labeling Instructions
===========================

• Carefully read the message.
• Assign one or more appropriate labels from the Label Set.
• If the message is vague or lacks sufficient context, assign the 'Unclear' label.
• Respond **only** in JSON format with the keys: "labels" (list of strings).
• IMPORTANT: Always return labels as an array of strings, even for single labels.

--- Example Output Format ---
{"labels": ["Emotional Distress"]}
{"labels": ["Attacking Behavior"]}
{"labels": ["Suicidal Reference"]}
{"labels": ["Safe/Neutral"]}
{"labels": ["Unclear"]}
"""

# %%
INPUT_FILE = Path("toxicity_parsed.xlsx")       
GEMINI_MODEL = "gemini-2.0-flash"  # Updated to available model
CHUNK_SIZE = 10
GEMINI_API_KEY = os.environ["GEMINI_API_KEY"]  # Fixed API key format

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

def label_text(text: str) -> dict[str, list[str]]:
    text = (text or "").strip()
    if not text:
        return {"labels": ["Unclear - Empty Text"]}
    
    prompt = f"{SYSTEM_PROMPT}\n\nText to classify:\n{text}"
    
    try:
        resp = client.models.generate_content(
            model=GEMINI_MODEL,
            contents=[prompt],
            config=types.GenerateContentConfig(
                response_mime_type="application/json", 
                temperature=0
            ),
        )
        candidate = resp.candidates[0]
        # Check finish reason
        if candidate.finish_reason != "STOP":
            return {"labels": ["Error - Response Blocked"]}
        
        # Check if content exists
        if candidate.content is None:
            return {"labels": ["Error - No Content"]}
        
        # Check if content has parts
        if not candidate.content.parts or len(candidate.content.parts) == 0:
            return {"labels": ["Error - No Parts"]}
        
        # Get the text from the first part
        response_content = candidate.content.parts[0].text
        if response_content is None:
            return {"labels": ["Error - No Text"]}
        
        # Parse JSON
        try:
            result = json.loads(response_content)
            if "labels" not in result:
                return {"labels": ["Error - Invalid Format"]}
            return {"labels": result["labels"]}
        except json.JSONDecodeError as e:
            return {"labels": ["Error - Invalid JSON"]}
            
    except Exception as e:
        print(f"API call failed: {e}")
        return {"labels": ["Error - API Failure"]}

# %%
def main() -> None:
    print(f"Loading data from {INPUT_FILE}…")
    try:
        all_sheets = pd.read_excel(INPUT_FILE, sheet_name=None)
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return

    # Gather every "body" column we can find
    bodies = (
        pd.concat(
            [df["body"] for df in all_sheets.values() if "body" in df.columns],
            ignore_index=True
        )
        .dropna()
        .astype(str)
    )

    subset_df = bodies.iloc[22000:].reset_index(drop=True).to_frame(name="body")
    subset_df["labels"] = ""  # placeholder column
    total_rows = len(subset_df)
    print(f"Selected {total_rows} messages for labelling.")

    # Pre-compute filenames
    ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    final_outfile = INPUT_FILE.with_name(f"toxicity_parsed_labelled_{ts}.xlsx")
    progress_file = INPUT_FILE.with_name(f"toxicity_parsed_labelled_cp_{ts}.xlsx")

    print("Starting labelling process…")
        
    for idx, msg in enumerate(tqdm(subset_df["body"], desc="Labelling", total=total_rows), 1):
        time.sleep(0.2)
                
        # Get labels for the message
        rec = label_text(msg)
        labels_list = rec.get("labels", ["Unclear - Processing Error"])
        subset_df.at[idx - 1, "labels"] = ", ".join(labels_list)

        # Checkpoint save
        if idx % CHUNK_SIZE == 0 or idx == total_rows:
            try:
                subset_df.iloc[:idx].to_excel(progress_file, index=False)
                print(f"✓ Checkpoint: ({idx}/{total_rows}) ➜ {progress_file}")
            except Exception as e:
                print(f"Warning: Could not save checkpoint: {e}")

    # Final save
    try:
        subset_df.to_excel(final_outfile, index=False)
        print(f"✓ Finished. Full file saved ➜ {final_outfile}")
    except Exception as e:
        print(f"Error saving final file: {e}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading data from toxicity_parsed.xlsx…
# Selected 13000 messages for labelling.
# Starting labelling process…
# Labelling:   0%|          | 0/13000 [00:00<?, ?it/s]
# ✓ Checkpoint: (10/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (20/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (30/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (40/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (50/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (60/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (70/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (80/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (90/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (1990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (2990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (3990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (4990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (5990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (6140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ...
# ✓ Checkpoint: (11000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (11990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12010/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12020/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12030/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12040/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12050/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12060/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12070/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12080/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12090/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12100/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12110/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12120/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12130/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12140/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12150/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12160/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12170/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12180/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12190/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12200/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12210/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12220/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12230/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12240/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12250/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12260/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12270/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12280/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12290/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12300/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12310/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12320/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12330/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12340/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12350/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12360/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12370/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12380/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12390/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12400/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12410/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12420/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12430/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12440/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12450/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12460/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12470/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12480/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12490/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12500/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12510/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12520/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12530/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12540/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12550/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12560/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12570/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12580/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12590/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12600/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12610/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12620/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12630/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12640/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12650/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12660/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12670/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12680/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12690/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12700/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12710/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12720/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12730/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12740/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12750/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12760/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12770/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12780/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12790/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12800/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12810/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12820/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12830/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12840/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12850/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12860/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12870/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12880/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12890/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12900/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12910/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12920/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12930/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12940/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12950/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12960/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12970/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12980/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (12990/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Checkpoint: (13000/13000) ➜ toxicity_parsed_labelled_cp_20250603_172311.xlsx
# ✓ Finished. Full file saved ➜ toxicity_parsed_labelled_20250603_172311.xlsx
