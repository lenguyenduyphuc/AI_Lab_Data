# %%
from pathlib import Path
import json
import time
import datetime
import os
import pandas as pd
from typing import Final, Dict, List
from tqdm.auto import tqdm
from google import genai
from google.genai import types

# %%
# --- Configuration ---
SYSTEM_PROMPT = """
You are an expert annotator responsible for labeling online messages to support AI systems that detect mental health risks, predatory behavior, and emotional distress. Your output will be used to train models for real-time safety monitoring.

Objective: Create high-quality labeled data for training AI models that can detect predatory behaviors, emotional distress, and mental health risks in online communications.

===========================
1) Label Set (Choose one or more)
===========================

• Suicidal Reference
  - Mentions or implies suicidal thoughts, ideation, or self-harm
  - Example: "Sometimes I think about ending it all."

• Emotional Distress
  - Signs of depression, anxiety, emotional suffering, psychological struggle
  - Example: "I just feel so lost lately, like nothing matters."

• Attacking Behavior
  - Bullying, sexually predatory content, threats, grooming, or intimidation
  - Example: "Don't tell your parents — it's our secret, okay?"

• Safe/Neutral
  - No concerning behavior, emotionally balanced, or informative
  - Example: "I got an A on my exam! So happy right now!"

• Unclear
  - Too vague or ambiguous to confidently assign a label
  - Example: "I'm fine." (without context)

===========================
2) Labeling Instructions
===========================

• Carefully read the message.
• Assign one or more appropriate labels from the Label Set.
• If the message is vague or lacks sufficient context, assign the 'Unclear' label.
• Respond **only** in JSON format with the keys: "labels" (list of strings).
• IMPORTANT: Always return labels as an array of strings, even for single labels.

--- Example Output Format ---
{"labels": ["Emotional Distress"]}
{"labels": ["Attacking Behavior"]}
{"labels": ["Suicidal Reference"]}
{"labels": ["Safe/Neutral"]}
{"labels": ["Unclear"]}
"""

# %%
INPUT_FILE = Path("Reddit_data_final.xlsx")       
GEMINI_MODEL = "gemini-2.5-flash-preview-05-20"  # Updated to available model
CHUNK_SIZE = 10
GEMINI_API_KEY = "AIzaSyDnWVOh73Hp_TB0VeGU1rLs0Vpb0t9MX80"  # Fixed API key format

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

def label_text(text: str) -> dict[str, list[str]]:
    text = (text or "").strip()
    if not text:
        return {"labels": ["Unclear - Empty Text"]}
    
    prompt = f"{SYSTEM_PROMPT}\n\nText to classify:\n{text}"
    
    try:
        resp = client.models.generate_content(
            model=GEMINI_MODEL,
            contents=[prompt],
            config=types.GenerateContentConfig(
                response_mime_type="application/json", 
                temperature=0
            ),
        )
        candidate = resp.candidates[0]
        # Check finish reason
        if candidate.finish_reason != "STOP":
            return {"labels": ["Error - Response Blocked"]}
        
        # Check if content exists
        if candidate.content is None:
            return {"labels": ["Error - No Content"]}
        
        # Check if content has parts
        if not candidate.content.parts or len(candidate.content.parts) == 0:
            return {"labels": ["Error - No Parts"]}
        
        # Get the text from the first part
        response_content = candidate.content.parts[0].text
        if response_content is None:
            return {"labels": ["Error - No Text"]}
        
        # Parse JSON
        try:
            result = json.loads(response_content)
            if "labels" not in result:
                return {"labels": ["Error - Invalid Format"]}
            return {"labels": result["labels"]}
        except json.JSONDecodeError as e:
            return {"labels": ["Error - Invalid JSON"]}
            
    except Exception as e:
        print(f"API call failed: {e}")
        return {"labels": ["Error - API Failure"]}

# %%
def main() -> None:
    print(f"Loading data from {INPUT_FILE}…")
    try:
        all_sheets = pd.read_excel(INPUT_FILE, sheet_name=None)
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return

    # Gather every "body" column we can find
    bodies = (
        pd.concat(
            [df["body"] for df in all_sheets.values() if "body" in df.columns],
            ignore_index=True
        )
        .dropna()
        .astype(str)
    )

    subset_df = bodies.iloc[13000:].reset_index(drop=True).to_frame(name="body")
    subset_df["labels"] = ""  # placeholder column
    total_rows = len(subset_df)
    print(f"Selected {total_rows} messages for labelling.")

    # Pre-compute filenames
    ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    final_outfile = INPUT_FILE.with_name(f"Data_labelled_{ts}.xlsx")
    progress_file = INPUT_FILE.with_name(f"Data_labelled_cp_{ts}.xlsx")

    print("Starting labelling process…")
        
    for idx, msg in enumerate(tqdm(subset_df["body"], desc="Labelling", total=total_rows), 1):
        time.sleep(0.2)
                
        # Get labels for the message
        rec = label_text(msg)
        labels_list = rec.get("labels", ["Unclear - Processing Error"])
        subset_df.at[idx - 1, "labels"] = ", ".join(labels_list)

        # Checkpoint save
        if idx % CHUNK_SIZE == 0 or idx == total_rows:
            try:
                subset_df.iloc[:idx].to_excel(progress_file, index=False)
                print(f"✓ Checkpoint: ({idx}/{total_rows}) ➜ {progress_file}")
            except Exception as e:
                print(f"Warning: Could not save checkpoint: {e}")

    # Final save
    try:
        subset_df.to_excel(final_outfile, index=False)
        print(f"✓ Finished. Full file saved ➜ {final_outfile}")
    except Exception as e:
        print(f"Error saving final file: {e}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading data from Reddit_data_final.xlsx…
# Selected 4838 messages for labelling.
# Starting labelling process…
# Labelling:   0%|          | 0/4838 [00:00<?, ?it/s]
# ✓ Checkpoint: (10/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (20/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (30/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (40/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (50/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (60/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (70/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (80/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (90/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (100/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (110/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (120/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (130/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (140/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (150/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (160/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (170/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (180/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (190/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (200/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (210/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (220/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (230/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (240/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (250/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (260/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (270/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (280/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (290/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (300/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (310/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (320/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (330/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (340/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (350/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (360/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (370/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (380/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (390/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (400/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (410/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (420/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (430/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (440/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (450/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (460/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (470/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (480/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (490/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (500/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (510/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (520/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (530/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (540/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (550/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (560/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (570/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (580/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (590/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (600/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (610/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (620/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (630/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (640/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (650/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (660/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (670/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (680/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (690/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (700/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (710/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (720/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (730/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (740/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (750/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (760/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (770/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (780/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (790/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (800/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (810/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (820/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (830/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (840/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (850/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (860/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (870/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (880/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (890/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (900/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (910/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (920/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (930/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (940/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (950/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (960/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (970/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (980/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (990/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1000/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1010/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1020/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1030/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1040/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1050/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1060/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1070/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1080/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1090/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1100/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1110/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1120/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1130/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1140/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1150/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1160/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1170/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1180/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1190/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1200/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1210/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1220/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1230/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1240/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1250/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1260/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1270/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1280/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1290/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1300/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1310/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1320/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1330/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1340/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1350/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1360/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1370/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1380/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1390/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1400/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1410/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1420/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1430/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1440/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1450/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1460/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1470/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1480/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1490/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1500/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1510/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1520/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1530/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1540/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (1550/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1560/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1570/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1580/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1590/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1600/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1610/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1620/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1630/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1640/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1650/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1660/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1670/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1680/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1690/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1700/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1710/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1720/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1730/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1740/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1750/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1760/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1770/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1780/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1790/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1800/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1810/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1820/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1830/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1840/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1850/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1860/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1870/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1880/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1890/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1900/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1910/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1920/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1930/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1940/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1950/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1960/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1970/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1980/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (1990/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2000/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2010/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2020/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2030/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2040/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2050/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2060/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2070/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2080/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2090/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2100/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2110/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2120/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2130/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2140/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2150/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2160/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2170/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2180/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2190/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2200/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2210/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2220/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2230/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2240/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2250/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2260/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2270/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2280/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2290/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2300/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2310/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2320/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2330/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2340/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2350/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2360/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2370/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2380/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2390/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2400/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2410/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2420/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2430/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2440/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2450/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2460/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2470/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2480/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2490/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2500/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2510/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2520/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2530/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2540/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2550/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2560/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2570/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2580/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2590/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2600/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2610/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (2620/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2630/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2640/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2650/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2660/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2670/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2680/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2690/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2700/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2710/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2720/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2730/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2740/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2750/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2760/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2770/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (2780/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2790/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2800/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2810/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2820/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2830/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2840/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2850/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2860/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2870/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2880/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2890/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2900/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2910/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2920/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2930/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2940/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2950/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2960/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2970/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2980/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (2990/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3000/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3010/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3020/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3030/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3040/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3050/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3060/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3070/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3080/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3090/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3100/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3110/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3120/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3130/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3140/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3150/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3160/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3170/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3180/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3190/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3200/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3210/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3220/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3230/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3240/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3250/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3260/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3270/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3280/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3290/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3300/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3310/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3320/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3330/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3340/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3350/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3360/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3370/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3380/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3390/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3400/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3410/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3420/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3430/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3440/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3450/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3460/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3470/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3480/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3490/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3500/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3510/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3520/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3530/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3540/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3550/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3560/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3570/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3580/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3590/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3600/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3610/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3620/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 502 Bad Gateway. {'message': '<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 502 (Server Error)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}\n  </style>\n  <a href=//www.google.com/><span id=logo aria-label=Google></span></a>\n  <p><b>502.</b> <ins>That’s an error.</ins>\n  <p>The server encountered a temporary error and could not complete your request.<p>Please try again in 30 seconds.  <ins>That’s all we know.</ins>\n', 'status': 'Bad Gateway'}
# ✓ Checkpoint: (3630/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3640/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3650/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3660/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3670/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3680/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3690/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3700/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3710/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3720/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3730/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3740/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3750/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3760/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3770/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3780/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3790/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3800/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3810/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3820/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3830/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3840/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3850/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (3860/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3870/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3880/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3890/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3900/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3910/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3920/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3930/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3940/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3950/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3960/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3970/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3980/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (3990/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4000/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4010/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4020/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4030/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The service is currently unavailable.', 'status': 'UNAVAILABLE'}}
# ✓ Checkpoint: (4040/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4050/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4060/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4070/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4080/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4090/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4100/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4110/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4120/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4130/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4140/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4150/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4160/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4170/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4180/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4190/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4200/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4210/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4220/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4230/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4240/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4250/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4260/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4270/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4280/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4290/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4300/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4310/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4320/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4330/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4340/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4350/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4360/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4370/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4380/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4390/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4400/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4410/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4420/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4430/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4440/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4450/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4460/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4470/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4480/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4490/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4500/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4510/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4520/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4530/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4540/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4550/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4560/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4570/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4580/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4590/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4600/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4610/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4620/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4630/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4640/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4650/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (4660/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4670/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4680/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4690/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4700/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4710/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4720/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4730/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4740/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4750/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4760/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4770/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The service is currently unavailable.', 'status': 'UNAVAILABLE'}}
# ✓ Checkpoint: (4780/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4790/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4800/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4810/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 'NoneType' object is not subscriptable
# ✓ Checkpoint: (4820/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# API call failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The service is currently unavailable.', 'status': 'UNAVAILABLE'}}
# ✓ Checkpoint: (4830/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Checkpoint: (4838/4838) ➜ Data_labelled_cp_20250529_150104.xlsx
# ✓ Finished. Full file saved ➜ Data_labelled_20250529_150104.xlsx
