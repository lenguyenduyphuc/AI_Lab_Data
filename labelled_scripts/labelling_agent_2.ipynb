# %%
from pathlib import Path
import json
import time
import datetime
import os
import pandas as pd
from tqdm.auto import tqdm
from google import genai
from google.genai import types

# %%
# --- Configuration ---
SYSTEM_PROMPT = """
You are an expert annotator responsible for labeling online messages to support AI systems that detect mental health risks, predatory behavior, and emotional distress. Your output will be used to train models for real-time safety monitoring.

Objective: Create high-quality labeled data for training AI models that can detect predatory behaviors, emotional distress, and mental health risks in online communications.

===========================
1) Label Set (Choose one or more)
===========================

• Suicidal Reference
  - Mentions or implies suicidal thoughts, ideation, or self-harm
  - Example: "Sometimes I think about ending it all."

• Emotional Distress
  - Signs of depression, anxiety, emotional suffering, psychological struggle
  - Example: "I just feel so lost lately, like nothing matters."

• Attacking Behavior
  - Bullying, sexually predatory content, threats, grooming, or intimidation
  - Example: "Don't tell your parents — it's our secret, okay?"

• Safe/Neutral
  - No concerning behavior, emotionally balanced, or informative
  - Example: "I got an A on my exam! So happy right now!"

• Unclear
  - Too vague or ambiguous to confidently assign a label
  - Example: "I'm fine." (without context)

===========================
2) Labeling Instructions
===========================

• Carefully read the message.
• Assign one or more appropriate labels from the Label Set.
• If the message is vague or lacks sufficient context, assign the 'Unclear' label.
• Respond **only** in JSON format with the keys: "labels" (list of strings).
• IMPORTANT: Always return labels as an array of strings, even for single labels.

--- Example Output Format ---
{"labels": ["Emotional Distress"]}
{"labels": ["Attacking Behavior"]}
{"labels": ["Suicidal Reference"]}
{"labels": ["Safe/Neutral"]}
{"labels": ["Unclear"]}
"""

# %%
INPUT_FILE = Path("twitter_sexism_parsed_dataset.xlsx")       
GEMINI_MODEL = "gemini-2.0-flash"  # Updated to available model
CHUNK_SIZE = 10
GEMINI_API_KEY = os.environ["GEMINI_API_KEY"]  # Fixed API key format

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

def label_text(text: str) -> dict[str, list[str]]:
    text = (text or "").strip()
    if not text:
        return {"labels": ["Unclear - Empty Text"]}
    
    prompt = f"{SYSTEM_PROMPT}\n\nText to classify:\n{text}"
    
    try:
        resp = client.models.generate_content(
            model=GEMINI_MODEL,
            contents=[prompt],
            config=types.GenerateContentConfig(
                response_mime_type="application/json", 
                temperature=0
            ),
        )
        candidate = resp.candidates[0]
        # Check finish reason
        if candidate.finish_reason != "STOP":
            return {"labels": ["Error - Response Blocked"]}
        
        # Check if content exists
        if candidate.content is None:
            return {"labels": ["Error - No Content"]}
        
        # Check if content has parts
        if not candidate.content.parts or len(candidate.content.parts) == 0:
            return {"labels": ["Error - No Parts"]}
        
        # Get the text from the first part
        response_content = candidate.content.parts[0].text
        if response_content is None:
            return {"labels": ["Error - No Text"]}
        
        # Parse JSON
        try:
            result = json.loads(response_content)
            if "labels" not in result:
                return {"labels": ["Error - Invalid Format"]}
            return {"labels": result["labels"]}
        except json.JSONDecodeError as e:
            return {"labels": ["Error - Invalid JSON"]}
            
    except Exception as e:
        print(f"API call failed: {e}")
        return {"labels": ["Error - API Failure"]}

# %%
def main() -> None:
    print(f"Loading data from {INPUT_FILE}…")
    try:
        all_sheets = pd.read_excel(INPUT_FILE, sheet_name=None)
    except Exception as e:
        print(f"Error reading Excel file: {e}")
        return

    # Gather every "body" column we can find
    bodies = (
        pd.concat(
            [df["body"] for df in all_sheets.values() if "body" in df.columns],
            ignore_index=True
        )
        .dropna()
        .astype(str)
    )

    subset_df = bodies.reset_index(drop=True).to_frame(name="body")
    subset_df["labels"] = ""  # placeholder column
    total_rows = len(subset_df)
    print(f"Selected {total_rows} messages for labelling.")

    # Pre-compute filenames
    ts = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    final_outfile = INPUT_FILE.with_name(f"twitter_sexism_parsed_dataset_labelled_{ts}.xlsx")
    progress_file = INPUT_FILE.with_name(f"twitter_sexism_parsed_dataset_labelled_cp_{ts}.xlsx")

    print("Starting labelling process…")
        
    for idx, msg in enumerate(tqdm(subset_df["body"], desc="Labelling", total=total_rows), 1):
        time.sleep(0.2)
                
        # Get labels for the message
        rec = label_text(msg)
        labels_list = rec.get("labels", ["Unclear - Processing Error"])
        subset_df.at[idx - 1, "labels"] = ", ".join(labels_list)

        # Checkpoint save
        if idx % CHUNK_SIZE == 0 or idx == total_rows:
            try:
                subset_df.iloc[:idx].to_excel(progress_file, index=False)
                print(f"✓ Checkpoint: ({idx}/{total_rows}) ➜ {progress_file}")
            except Exception as e:
                print(f"Warning: Could not save checkpoint: {e}")

    # Final save
    try:
        subset_df.to_excel(final_outfile, index=False)
        print(f"✓ Finished. Full file saved ➜ {final_outfile}")
    except Exception as e:
        print(f"Error saving final file: {e}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Loading data from Twitter_parsed.xlsx…
# Selected 7008 messages for labelling.
# Starting labelling process…
# Labelling:   0%|          | 0/7008 [00:00<?, ?it/s]
# ✓ Checkpoint: (10/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (20/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (30/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (40/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (50/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (60/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (70/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (80/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (90/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (1990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# API call failed: 502 Bad Gateway. {'message': '<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 502 (Server Error)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-border-image:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) 0}}@media only screen and (-webkit-min-device-pixel-ratio:2){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat;-webkit-background-size:100% 100%}}#logo{display:inline-block;height:54px;width:150px}\n  </style>\n  <a href=//www.google.com/><span id=logo aria-label=Google></span></a>\n  <p><b>502.</b> <ins>That’s an error.</ins>\n  <p>The server encountered a temporary error and could not complete your request.<p>Please try again in 30 seconds.  <ins>That’s all we know.</ins>\n', 'status': 'Bad Gateway'}
# ✓ Checkpoint: (2410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (2990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (3990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (4990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (5990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6010/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6020/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6030/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6040/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6050/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6060/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6070/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6080/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6090/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6100/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6110/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6120/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6130/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6140/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6150/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6160/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6170/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6180/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6190/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6200/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6210/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6220/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6230/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6240/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6250/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6260/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6270/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6280/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6290/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6300/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6310/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6320/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6330/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6340/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6350/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6360/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6370/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6380/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6390/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6400/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6410/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6420/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6430/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6440/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6450/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6460/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6470/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6480/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6490/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6500/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6510/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6520/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6530/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6540/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6550/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6560/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6570/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6580/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6590/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6600/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6610/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6620/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6630/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6640/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6650/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6660/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6670/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6680/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6690/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6700/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6710/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6720/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6730/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6740/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6750/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6760/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6770/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6780/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6790/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6800/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6810/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6820/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6830/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6840/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6850/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6860/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6870/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6880/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6890/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6900/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6910/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6920/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6930/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6940/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6950/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6960/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6970/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6980/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (6990/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (7000/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Checkpoint: (7008/7008) ➜ Twitter_parsed_labelled_cp_20250603_172117.xlsx
# ✓ Finished. Full file saved ➜ Twitter_parsed_labelled_20250603_172117.xlsx
